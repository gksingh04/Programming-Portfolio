# %%
import numpy as np

# %%
import pandas as pd

# %%
# qns 1

# %%
pd.read_csv('population_india_census2011.csv',encoding='unicode_escape')
# Out:
#     Sno     Region                   State / Union Territory  Population  \
# 0     1      North                             Uttar Pradesh   199812341
# 1     2       West                               Maharashtra   112374333
# 2     3      North                                     Bihar   104099452
# 3     4       East                               West Bengal    91276115
# 4     5     Cntral                            Madhya Pradesh    72626809
# 5     6      South                                Tamil Nadu    72147030
# 6     7      North                                 Rajasthan    68548437
# 7     8      South                                 Karnataka    61095297
# 8     9       West                                   Gujarat    60439692
# 9    10      South                            Andhra Pradesh    49577103
# 10   11       East                                    Odisha    41974218
# 11   12      South                                 Telengana    35003674
# ...

# %%
pop = pd.read_csv('population_india_census2011.csv',encoding='unicode_escape')

# %%
# qns 2 a

# %%
pop.head()
# Out:
#    Sno  Region State / Union Territory  Population  Rural population  \
# 0    1   North           Uttar Pradesh   199812341         155317278
# 1    2    West             Maharashtra   112374333          61556074
# 2    3   North                   Bihar   104099452          92341436
# 3    4    East             West Bengal    91276115          62183113
# 4    5  Cntral          Madhya Pradesh    72626809          52557404
#
#    Urban population          Area  Gender Ratio
# 0          44495063  240,928 km2            912
# 1          50818259  307,713 km2            929
# 2          11758016   94,163 km2            918
# 3          29093002   88,752 km2            953
# 4          20069405   308,245 km2           931

# %%
# qns 2 b

# %%
pop.head(10)
# Out:
#    Sno  Region State / Union Territory  Population  Rural population  \
# 0    1   North           Uttar Pradesh   199812341         155317278
# 1    2    West             Maharashtra   112374333          61556074
# 2    3   North                   Bihar   104099452          92341436
# 3    4    East             West Bengal    91276115          62183113
# 4    5  Cntral          Madhya Pradesh    72626809          52557404
# 5    6   South              Tamil Nadu    72147030          37229590
# 6    7   North               Rajasthan    68548437          51500352
# 7    8   South               Karnataka    61095297          37469335
# 8    9    West                 Gujarat    60439692          34694609
# 9   10   South          Andhra Pradesh    49577103          34966693
#
#    Urban population          Area  Gender Ratio
# 0          44495063  240,928 km2            912
# 1          50818259  307,713 km2            929
# 2          11758016   94,163 km2            918
# ...

# %%
# qns 3

# %%
list(pop.columns)
# Out:
# ['Sno',
#  'Region',
#  'State / Union Territory',
#  'Population',
#  'Rural population',
#  'Urban population',
#  'Area',
#  'Gender Ratio']

# %%
# qns 4

# %%
len(pop['State / Union Territory'].unique())
# Out:
# 36

# %%
# qns 5

# %%
pop['State / Union Territory'].unique()
# Out:
# array(['Uttar Pradesh', 'Maharashtra', 'Bihar', 'West Bengal',
#        'Madhya Pradesh', 'Tamil Nadu', 'Rajasthan', 'Karnataka',
#        'Gujarat', 'Andhra Pradesh', 'Odisha', 'Telengana', 'Kerala',
#        'Jharkhand', 'Assam', 'Punjab', 'Chhattisgarh', 'Haryana',
#        'Uttarakhand', 'Himachal Pradesh', 'Tripura', 'Meghalaya',
#        'Manipur', 'Nagaland', 'Goa', 'Arunachal Pradesh', 'Mizoram',
#        'Sikkim', 'Delhi', 'Jammu and Kashmir', 'Puducherry', 'Chandigarh',
#        'Dadra and Nagar Haveli and Daman and Diu',
#        'Andaman and Nicobar Islands', 'Ladakh', 'Lakshadweep'],
#       dtype=object)

# %%
# qns 6

# %%
pop['Region'].value_counts()
# Out:
# North        11
# South         8
# Noth East     8
# West          4
# Central       2
# East          2
# Cntral        1
# Name: Region, dtype: int64

# %%
# qns 7

# %%
print(pop[['State / Union Territory', 'Population']][pop.Population == pop.Population.max()])
# Out:
#   State / Union Territory  Population
# 0           Uttar Pradesh   199812341

# %%
# qns 8

# %%
print(pop[['Region', 'Population']][pop.Population == pop.Population.max()])
# Out:
#   Region  Population
# 0  North   199812341

# %%
# qns 10

# %%
pop[pop['State / Union Territory'].str.contains("Pradesh")]
# Out:
#     Sno     Region State / Union Territory  Population  Rural population  \
# 0     1      North           Uttar Pradesh   199812341         155317278
# 4     5     Cntral          Madhya Pradesh    72626809          52557404
# 9    10      South          Andhra Pradesh    49577103          34966693
# 19   20      North        Himachal Pradesh     6864602           6176050
# 25   26  Noth East       Arunachal Pradesh     1383727           1066358
#
#     Urban population          Area  Gender Ratio
# 0           44495063  240,928 km2            912
# 4           20069405   308,245 km2           931
# 9           14610410   162,968 km2           993
# 19            688552    55,673 km2           972
# 25            317369    83,743 km2           938

# %%
# qns 9

# %%
pop['Gender Ratio']>900
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# Name: Gender Ratio, dtype: bool

# %%
# qns 12

# %%
pop['Highest divison'] = pop['Rural population']/pop['Urban population']
pop['Highest divison']
# Out:
# 0     3.490663
# 1     1.211298
# 2     7.853488
# 3     2.137391
# 4     2.618782
# 5     1.066218
# 6     3.020888
# 7     1.585939
# 8     1.347621
# 9     2.393273
# 10    4.993187
# 11    1.572161
# 12    1.096405
# 13    3.158311
# 14    6.094527
# 15    1.667848
# 16    3.302540
# 17    1.867130
# 18    2.307699
# 19    8.969620
# 20    2.821213
# 21    3.982600
# 22    2.310161
# 23    2.465184
# 24    0.608428
# 25    3.359994
# 26    0.918961
# 27    2.975680
# 28    0.025600
# 29    2.830082
# 30    0.463440
# 31    0.028244
# 32    0.711489
# 33    1.652354
# 34    0.190476
# 35    0.280954
# Name: Highest divison, dtype: float64

# %%
# qns 11
